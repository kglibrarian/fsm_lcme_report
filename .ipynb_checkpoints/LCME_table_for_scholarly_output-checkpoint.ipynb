# %%
## Import dependencies
import sys, os
import pandas as pd

# %%
# Step 1: Load the CSV file
file_path = 'data\\20241029_LCME.csv'  # Replace with your CSV file path
lcme_df = pd.read_csv(file_path)
lcme_df.head()
# Out:
#    Group ID  User ID             Name                     Position  \
# 0        15    11346    Leah Neubauer          Associate Professor
# 1        15     3773    Joshua Hauser                    Professor
# 2        15     2617  William Grobman            Adjunct Professor
# 3        15    13109     Emily Miller  Adjunct Associate Professor
# 4        15    10459         Lynn Yee          Associate Professor
#
#                               Department                        School  \
# 0                   Preventive Medicine;   Feinberg School of Medicine
# 1  Medicine, Hospital Medicine Division;   Feinberg School of Medicine
# 2             Obstetrics and Gynecology;   Feinberg School of Medicine
# 3             Obstetrics and Gynecology;   Feinberg School of Medicine
# 4             Obstetrics and Gynecology;   Feinberg School of Medicine
#
#    Employee ID   Net ID  Is Current Staff  Is Academic  ...  \
# 0      2334590  lcn8717                 1            1  ...
# 1      1049388   jmh734                 1            1  ...
# 2      1027416   wag063                 1            1  ...
# 3      2698434   emi373                 1            1  ...
# 4      2001454   lmy505                 1            1  ...
#
#                Scopus       Web of Science                       Crossref  \
# 0  2-s2.0-85184902556                  NaN               10.1002/ev.20577
# 1  2-s2.0-85074861554                  NaN  10.1136/bmjspcare-2019-001928
# 2  2-s2.0-85125994522  WOS:001188015800009            10.1055/a-1745-0091
# 3  2-s2.0-85125994522  WOS:001188015800009            10.1055/a-1745-0091
# 4  2-s2.0-85125621164  WOS:000758393600002         10.1055/s-0042-1743184
#
#        PubMed Europe PubMed Central Max PR Pub ID Max PR NIHMS Max PR PMCID  \
# 0         NaN                   NaN       1137050          NaN          NaN
# 1  31685523.0          MED:31685523       3261956          NaN          NaN
# 2  35045575.0          MED:35045575       3281092          NaN          NaN
# 3  35045575.0          MED:35045575       3281092          NaN          NaN
# 4  35189652.0          MED:35189652       3281107          NaN          NaN
#
#   Max PR PMID    Max PR PubMed
# 0         NaN              NaN
# 1         NaN  pubmed:31685523
# 2         NaN  pubmed:35045575
# 3         NaN  pubmed:35045575
# 4         NaN  pubmed:35189652
#
# [5 rows x 36 columns]

# %%
# Step 2: Remove rows where the department is NaN or empty
lcme_df_2 = lcme_df[lcme_df['Department'].notna() & (lcme_df['Department'] != '')]

# Check for any remaining NaN values in the Department column
print("Number of NaN values in 'Department':", lcme_df_2['Department'].isna().sum())

# Check for any remaining empty strings in the Department column
print("Number of empty strings in 'Department':", (lcme_df_2['Department'] == '').sum())

# Display unique values in the Department column to confirm no blanks
print("Unique values in 'Department':", lcme_df_2['Department'].unique())

# Check the shape before and after removing rows
print("Original DataFrame shape:", lcme_df.shape)
print("Filtered DataFrame shape:", lcme_df_2.shape)

lcme_df_2.head()
# Out:
# Number of NaN values in 'Department': 0
# Number of empty strings in 'Department': 0
# Unique values in 'Department': ['Preventive Medicine;' 'Medicine, Hospital Medicine Division;'
#  'Obstetrics and Gynecology;' 'Dermatology;' 'Ophthalmology;' 'Urology;'
#  'Medical Social Sciences;' 'Emergency Medicine;' 'Pediatrics;'
#  'Psychiatry and Behavioral Sciences;' 'Medicine, Endocrinology Division;'
#  'Surgery, Cardiac Surgery Division;' 'Medicine, Hepatology Division;'
#  'Surgery, Transplant Surgery Division;'
#  'Medicine, General Medicine Division;' 'Neurological Surgery;'
#  'Medicine, Cardiology Division;' 'Pediatrics (Stanley Manne);'
#  'Medicine, Hematology Oncology Division;'
#  'Physical Therapy and Human Movement Sciences;'
#  'Surgery, Surgical Oncology Division;' 'Medicine, Rheumatology Division;'
#  'Center for Genetic Medicine;' 'Neurology;' 'Orthopaedic Surgery;'
#  'Medicine, Pulmonary Division;' 'Physical Medicine and Rehabilitation;'
#  'Radiology;' 'Surgery;' 'Pathology;' 'Otolaryngology;'
#  'Surgery, Trauma and Critical Care Division;'
#  'Surgery, Thoracic Surgery Division;' 'Anesthesiology;'
#  'Medicine, Gastroenterology Division;' 'Galter Health Science Library;'
#  'Medicine, Allergy Division;' 'Microbiology-Immunology;'
#  'Medicine, Nephrology Division;'
#  'NU Clinical and Translational Sciences Institute;' 'Medical Education;'
#  'Surgery, Plastic Surgery Division;'
#  'Buehler Center for Health Policy and Economics;'
#  'Medicine, Infectious Diseases Division;' 'Radiation Oncology;'
#  'Pharmacology;' 'Biochemistry and Molecular Genetics;'
#  'Mesulam Center for Cognitive Neurology and Alzheimers Disease;'
#  'Neuroscience;' 'Surgery, Gastrointestinal/Endo Division;'
#  'Medicine, Geriatrics Division;' 'Surgery, Vascular Surgery Division;'
#  'Center for Education in Medicine;' 'Cell &amp;'
#  'Surgery, Clinical Trials Unit;' 'Medicine;'
#  'Surgery, Breast Surgery Division;' 'Faculty Affairs;'
#  'Molecular Biosciences;' 'Family and Community Medicine;'
#  'Lurie Cancer Center;' 'Feinberg Cardiovascular Research Institute;'
#  'Office of Finance and Administration;'
#  'Medical Education, Physician Assistant Program;'
#  'Otolaryngology, Dental Surgery Division;'
#  'Medical Scientist Training Program;' 'Office for Research;'
#  'Center for Food Allergy and Asthma Research;'
#  'Northwestern University Interdepartmental Neurosciences;'
#  'Center for Education in Health Sciences;' 'Integrated Grad Program;'
#  'Global Health Institute;']
# Original DataFrame shape: (11603, 36)
# Filtered DataFrame shape: (11572, 36)
#    Group ID  User ID             Name                     Position  \
# 0        15    11346    Leah Neubauer          Associate Professor
# 1        15     3773    Joshua Hauser                    Professor
# 2        15     2617  William Grobman            Adjunct Professor
# 3        15    13109     Emily Miller  Adjunct Associate Professor
# 4        15    10459         Lynn Yee          Associate Professor
#
#                               Department                        School  \
# 0                   Preventive Medicine;   Feinberg School of Medicine
# 1  Medicine, Hospital Medicine Division;   Feinberg School of Medicine
# 2             Obstetrics and Gynecology;   Feinberg School of Medicine
# 3             Obstetrics and Gynecology;   Feinberg School of Medicine
# 4             Obstetrics and Gynecology;   Feinberg School of Medicine
#
#    Employee ID   Net ID  Is Current Staff  Is Academic  ...  \
# 0      2334590  lcn8717                 1            1  ...
# 1      1049388   jmh734                 1            1  ...
# 2      1027416   wag063                 1            1  ...
# 3      2698434   emi373                 1            1  ...
# 4      2001454   lmy505                 1            1  ...
#
#                Scopus       Web of Science                       Crossref  \
# 0  2-s2.0-85184902556                  NaN               10.1002/ev.20577
# 1  2-s2.0-85074861554                  NaN  10.1136/bmjspcare-2019-001928
# 2  2-s2.0-85125994522  WOS:001188015800009            10.1055/a-1745-0091
# 3  2-s2.0-85125994522  WOS:001188015800009            10.1055/a-1745-0091
# 4  2-s2.0-85125621164  WOS:000758393600002         10.1055/s-0042-1743184
#
#        PubMed Europe PubMed Central Max PR Pub ID Max PR NIHMS Max PR PMCID  \
# 0         NaN                   NaN       1137050          NaN          NaN
# 1  31685523.0          MED:31685523       3261956          NaN          NaN
# 2  35045575.0          MED:35045575       3281092          NaN          NaN
# 3  35045575.0          MED:35045575       3281092          NaN          NaN
# 4  35189652.0          MED:35189652       3281107          NaN          NaN
#
#   Max PR PMID    Max PR PubMed
# 0         NaN              NaN
# 1         NaN  pubmed:31685523
# 2         NaN  pubmed:35045575
# 3         NaN  pubmed:35045575
# 4         NaN  pubmed:35189652
#
# [5 rows x 36 columns]

# %%
# Step 3: Remove trailing semicolons from department names
lcme_df_2['Department'] = lcme_df_2['Department'].str.rstrip(';')

# Check for any departments with a trailing semicolon
print("Departments with trailing semicolons:", lcme_df_2[lcme_df_2['Department'].str.endswith(';')])

# Display unique department names to confirm no trailing semicolons
print("Unique department names:", lcme_df_2['Department'].unique())

lcme_df_2.head()
# Out:
# Departments with trailing semicolons: Empty DataFrame
# Columns: [Group ID, User ID, Name, Position, Department, School, Employee ID, Net ID, Is Current Staff, Is Academic, Publication ID, Publication-Date, authors, title, Canonical Journal Title, journal, volume, issue, pagination Begin, pagination End, doi, ISSN, eissn, Types, Type, pr Pub ID, Scopus, Web of Science, Crossref, PubMed, Europe PubMed Central, Max PR Pub ID, Max PR NIHMS, Max PR PMCID, Max PR PMID, Max PR PubMed]
# Index: []
#
# [0 rows x 36 columns]
# Unique department names: ['Preventive Medicine' 'Medicine, Hospital Medicine Division'
#  'Obstetrics and Gynecology' 'Dermatology' 'Ophthalmology' 'Urology'
#  'Medical Social Sciences' 'Emergency Medicine' 'Pediatrics'
#  'Psychiatry and Behavioral Sciences' 'Medicine, Endocrinology Division'
#  'Surgery, Cardiac Surgery Division' 'Medicine, Hepatology Division'
#  'Surgery, Transplant Surgery Division'
#  'Medicine, General Medicine Division' 'Neurological Surgery'
#  'Medicine, Cardiology Division' 'Pediatrics (Stanley Manne)'
#  'Medicine, Hematology Oncology Division'
#  'Physical Therapy and Human Movement Sciences'
#  'Surgery, Surgical Oncology Division' 'Medicine, Rheumatology Division'
#  'Center for Genetic Medicine' 'Neurology' 'Orthopaedic Surgery'
#  'Medicine, Pulmonary Division' 'Physical Medicine and Rehabilitation'
#  'Radiology' 'Surgery' 'Pathology' 'Otolaryngology'
#  'Surgery, Trauma and Critical Care Division'
#  'Surgery, Thoracic Surgery Division' 'Anesthesiology'
#  'Medicine, Gastroenterology Division' 'Galter Health Science Library'
#  'Medicine, Allergy Division' 'Microbiology-Immunology'
#  'Medicine, Nephrology Division'
#  'NU Clinical and Translational Sciences Institute' 'Medical Education'
#  'Surgery, Plastic Surgery Division'
#  'Buehler Center for Health Policy and Economics'
#  'Medicine, Infectious Diseases Division' 'Radiation Oncology'
#  'Pharmacology' 'Biochemistry and Molecular Genetics'
#  'Mesulam Center for Cognitive Neurology and Alzheimers Disease'
#  'Neuroscience' 'Surgery, Gastrointestinal/Endo Division'
#  'Medicine, Geriatrics Division' 'Surgery, Vascular Surgery Division'
#  'Center for Education in Medicine' 'Cell &amp'
#  'Surgery, Clinical Trials Unit' 'Medicine'
#  'Surgery, Breast Surgery Division' 'Faculty Affairs'
#  'Molecular Biosciences' 'Family and Community Medicine'
#  'Lurie Cancer Center' 'Feinberg Cardiovascular Research Institute'
#  'Office of Finance and Administration'
#  'Medical Education, Physician Assistant Program'
#  'Otolaryngology, Dental Surgery Division'
#  'Medical Scientist Training Program' 'Office for Research'
#  'Center for Food Allergy and Asthma Research'
#  'Northwestern University Interdepartmental Neurosciences'
#  'Center for Education in Health Sciences' 'Integrated Grad Program'
#  'Global Health Institute']
# C:\Users\keg827\AppData\Local\Temp\ipykernel_29440\3084946903.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lcme_df_2['Department'] = lcme_df_2['Department'].str.rstrip(';')
#    Group ID  User ID             Name                     Position  \
# 0        15    11346    Leah Neubauer          Associate Professor
# 1        15     3773    Joshua Hauser                    Professor
# 2        15     2617  William Grobman            Adjunct Professor
# 3        15    13109     Emily Miller  Adjunct Associate Professor
# 4        15    10459         Lynn Yee          Associate Professor
#
#                              Department                        School  \
# 0                   Preventive Medicine   Feinberg School of Medicine
# 1  Medicine, Hospital Medicine Division   Feinberg School of Medicine
# 2             Obstetrics and Gynecology   Feinberg School of Medicine
# 3             Obstetrics and Gynecology   Feinberg School of Medicine
# 4             Obstetrics and Gynecology   Feinberg School of Medicine
#
#    Employee ID   Net ID  Is Current Staff  Is Academic  ...  \
# 0      2334590  lcn8717                 1            1  ...
# 1      1049388   jmh734                 1            1  ...
# 2      1027416   wag063                 1            1  ...
# 3      2698434   emi373                 1            1  ...
# 4      2001454   lmy505                 1            1  ...
#
#                Scopus       Web of Science                       Crossref  \
# 0  2-s2.0-85184902556                  NaN               10.1002/ev.20577
# 1  2-s2.0-85074861554                  NaN  10.1136/bmjspcare-2019-001928
# 2  2-s2.0-85125994522  WOS:001188015800009            10.1055/a-1745-0091
# 3  2-s2.0-85125994522  WOS:001188015800009            10.1055/a-1745-0091
# 4  2-s2.0-85125621164  WOS:000758393600002         10.1055/s-0042-1743184
#
#        PubMed Europe PubMed Central Max PR Pub ID Max PR NIHMS Max PR PMCID  \
# 0         NaN                   NaN       1137050          NaN          NaN
# 1  31685523.0          MED:31685523       3261956          NaN          NaN
# 2  35045575.0          MED:35045575       3281092          NaN          NaN
# 3  35045575.0          MED:35045575       3281092          NaN          NaN
# 4  35189652.0          MED:35189652       3281107          NaN          NaN
#
#   Max PR PMID    Max PR PubMed
# 0         NaN              NaN
# 1         NaN  pubmed:31685523
# 2         NaN  pubmed:35045575
# 3         NaN  pubmed:35045575
# 4         NaN  pubmed:35189652
#
# [5 rows x 36 columns]

# %%
# Step 4: Replace instances of different school names with 'Feinberg School of Medicine'
school_names_to_replace = [' Developmental Biology; Feinberg School of Medicine',
                            'Developmental Biology; Feinberg School of Medicine',
                            'Office for Research', 
                            'ISGMH - Institute for Sexual and Gender Minority Health and Wellbeing', 
                            'Office for Research Safety', 
                            ' Judd A. and Marjorie Weinberg College of Arts and Sciences',
                            'Judd A. and Marjorie Weinberg College of Arts and Sciences',
                            'DevSci - Institute for Innovations in Developmental Sciences', 
                            'Office for Research Information Technology',
                            'NU Clinical and Translational Sciences Institute', 
                            'Office for Research', 
                            'Office of Finance and Administration', 
                            ]  # Add any variations here

lcme_df_2['School'] = lcme_df_2['School'].str.strip().replace(school_names_to_replace, 'Feinberg School of Medicine')

# Display unique department names
print("Unique department names after replacement:", lcme_df_2['School'].unique())

lcme_df_2.head()
# Out:
# Unique department names after replacement: ['Feinberg School of Medicine']
# C:\Users\keg827\AppData\Local\Temp\ipykernel_29440\3162126243.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lcme_df_2['School'] = lcme_df_2['School'].str.strip().replace(school_names_to_replace, 'Feinberg School of Medicine')
#    Group ID  User ID             Name                     Position  \
# 0        15    11346    Leah Neubauer          Associate Professor
# 1        15     3773    Joshua Hauser                    Professor
# 2        15     2617  William Grobman            Adjunct Professor
# 3        15    13109     Emily Miller  Adjunct Associate Professor
# 4        15    10459         Lynn Yee          Associate Professor
#
#                   Department                       School  Employee ID  \
# 0        Preventive Medicine  Feinberg School of Medicine      2334590
# 1                   Medicine  Feinberg School of Medicine      1049388
# 2  Obstetrics and Gynecology  Feinberg School of Medicine      1027416
# 3  Obstetrics and Gynecology  Feinberg School of Medicine      2698434
# 4  Obstetrics and Gynecology  Feinberg School of Medicine      2001454
#
#     Net ID  Is Current Staff  Is Academic  ...              Scopus  \
# 0  lcn8717                 1            1  ...  2-s2.0-85184902556
# 1   jmh734                 1            1  ...  2-s2.0-85074861554
# 2   wag063                 1            1  ...  2-s2.0-85125994522
# 3   emi373                 1            1  ...  2-s2.0-85125994522
# 4   lmy505                 1            1  ...  2-s2.0-85125621164
#
#         Web of Science                       Crossref      PubMed  \
# 0                  NaN               10.1002/ev.20577         NaN
# 1                  NaN  10.1136/bmjspcare-2019-001928  31685523.0
# 2  WOS:001188015800009            10.1055/a-1745-0091  35045575.0
# 3  WOS:001188015800009            10.1055/a-1745-0091  35045575.0
# 4  WOS:000758393600002         10.1055/s-0042-1743184  35189652.0
#
#   Europe PubMed Central Max PR Pub ID Max PR NIHMS Max PR PMCID Max PR PMID  \
# 0                   NaN       1137050          NaN          NaN         NaN
# 1          MED:31685523       3261956          NaN          NaN         NaN
# 2          MED:35045575       3281092          NaN          NaN         NaN
# 3          MED:35045575       3281092          NaN          NaN         NaN
# 4          MED:35189652       3281107          NaN          NaN         NaN
#
#      Max PR PubMed
# 0              NaN
# 1  pubmed:31685523
# 2  pubmed:35045575
# 3  pubmed:35045575
# 4  pubmed:35189652
#
# [5 rows x 36 columns]

# %%
# Step 3: Define the department mapping
department_mapping = {
    'Cell & Developmental Biology': ['Cell &amp'],
    'Medical Education': ['Medical Education, Physician Assistant Program',
                          'Medical Scientist Training Program',
                          ],
    'Medicine': ['Medicine, Allergy Division', 
                            'Medicine, Cardiology Division', 
                            'Medicine, Endocrinology Division', 
                            'Medicine, Gastroenterology Division', 
                            'Medicine, General Medicine Division', 
                            'Medicine, Geriatrics Division', 
                            'Medicine, Hematology Oncology Division', 
                            'Medicine, Hepatology Division', 
                            'Medicine, Hospital Medicine Division', 
                            'Medicine, Infectious Diseases Division', 
                            'Medicine, Nephrology Division', 
                            'Medicine, Pulmonary Division', 
                            'Medicine, Rheumatology Division' 
                            ],
    'Neurology': ['Mesulam Center for Cognitive Neurology and Alzheimers Disease'
                    'Neuroscience',
                    'Northwestern University Interdepartmental Neurosciences' 
                    ],
    'Otolaryngology': ['Otolaryngology, Dental Surgery Division'],
    'Pediatrics': ['Pediatrics (Stanley Manne)'],
    'Surgery':['Surgery, Breast Surgery Division', 
                'Surgery, Cardiac Surgery Division', 
                'Surgery, Clinical Trials Unit', 
                'Surgery, Gastrointestinal/Endo Division', 
                'Surgery, Plastic Surgery Division', 
                'Surgery, Surgical Oncology Division', 
                'Surgery, Thoracic Surgery Division', 
                'Surgery, Transplant Surgery Division', 
                'Surgery, Trauma and Critical Care Division', 
                'Surgery, Vascular Surgery Division'
                  ]
    
    # Add more mappings as needed
}

# Step 4: Create a reverse mapping for the replace function
replace_dict = {old_name: new_name for new_name, old_names in department_mapping.items() for old_name in old_names}

# Step 5: Replace department names
lcme_df_2['Department'] = lcme_df_2['Department'].replace(replace_dict)

## Print unique department names after replacement
print("Unique department names after replacement:", lcme_df_2['Department'].unique())

lcme_df_2.head()
# Out:
# Unique department names after replacement: ['Preventive Medicine' 'Medicine' 'Obstetrics and Gynecology'
#  'Dermatology' 'Ophthalmology' 'Urology' 'Medical Social Sciences'
#  'Emergency Medicine' 'Pediatrics' 'Psychiatry and Behavioral Sciences'
#  'Surgery' 'Neurological Surgery'
#  'Physical Therapy and Human Movement Sciences'
#  'Center for Genetic Medicine' 'Neurology' 'Orthopaedic Surgery'
#  'Physical Medicine and Rehabilitation' 'Radiology' 'Pathology'
#  'Otolaryngology' 'Anesthesiology' 'Galter Health Science Library'
#  'Microbiology-Immunology'
#  'NU Clinical and Translational Sciences Institute' 'Medical Education'
#  'Buehler Center for Health Policy and Economics' 'Radiation Oncology'
#  'Pharmacology' 'Biochemistry and Molecular Genetics'
#  'Center for Education in Medicine' 'Cell & Developmental Biology'
#  'Faculty Affairs' 'Molecular Biosciences' 'Family and Community Medicine'
#  'Lurie Cancer Center' 'Feinberg Cardiovascular Research Institute'
#  'Office of Finance and Administration' 'Office for Research'
#  'Center for Food Allergy and Asthma Research'
#  'Center for Education in Health Sciences' 'Integrated Grad Program'
#  'Global Health Institute']
# C:\Users\keg827\AppData\Local\Temp\ipykernel_29440\3708047941.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lcme_df_2['Department'] = lcme_df_2['Department'].replace(replace_dict)
#    Group ID  User ID             Name                     Position  \
# 0        15    11346    Leah Neubauer          Associate Professor
# 1        15     3773    Joshua Hauser                    Professor
# 2        15     2617  William Grobman            Adjunct Professor
# 3        15    13109     Emily Miller  Adjunct Associate Professor
# 4        15    10459         Lynn Yee          Associate Professor
#
#                   Department                       School  Employee ID  \
# 0        Preventive Medicine  Feinberg School of Medicine      2334590
# 1                   Medicine  Feinberg School of Medicine      1049388
# 2  Obstetrics and Gynecology  Feinberg School of Medicine      1027416
# 3  Obstetrics and Gynecology  Feinberg School of Medicine      2698434
# 4  Obstetrics and Gynecology  Feinberg School of Medicine      2001454
#
#     Net ID  Is Current Staff  Is Academic  ...              Scopus  \
# 0  lcn8717                 1            1  ...  2-s2.0-85184902556
# 1   jmh734                 1            1  ...  2-s2.0-85074861554
# 2   wag063                 1            1  ...  2-s2.0-85125994522
# 3   emi373                 1            1  ...  2-s2.0-85125994522
# 4   lmy505                 1            1  ...  2-s2.0-85125621164
#
#         Web of Science                       Crossref      PubMed  \
# 0                  NaN               10.1002/ev.20577         NaN
# 1                  NaN  10.1136/bmjspcare-2019-001928  31685523.0
# 2  WOS:001188015800009            10.1055/a-1745-0091  35045575.0
# 3  WOS:001188015800009            10.1055/a-1745-0091  35045575.0
# 4  WOS:000758393600002         10.1055/s-0042-1743184  35189652.0
#
#   Europe PubMed Central Max PR Pub ID Max PR NIHMS Max PR PMCID Max PR PMID  \
# 0                   NaN       1137050          NaN          NaN         NaN
# 1          MED:31685523       3261956          NaN          NaN         NaN
# 2          MED:35045575       3281092          NaN          NaN         NaN
# 3          MED:35045575       3281092          NaN          NaN         NaN
# 4          MED:35189652       3281107          NaN          NaN         NaN
#
#      Max PR PubMed
# 0              NaN
# 1  pubmed:31685523
# 2  pubmed:35045575
# 3  pubmed:35045575
# 4  pubmed:35189652
#
# [5 rows x 36 columns]

# %%
# Step 6: Define departments to drop
departments_to_drop = ['Buehler Center for Health Policy and Economics', 
                        'Center for Education in Health Sciences', 
                        'Center for Education in Medicine', 
                        'Center for Food Allergy and Asthma Research', 
                        'Center for Genetic Medicine',
                        'Faculty Affairs', 
                        'Feinberg Cardiovascular Research Institute', 
                        'Galter Health Science Library', 
                        'Global Health Institute', 
                        'Integrated Grad Program', 
                        'Lurie Cancer Center',
                        'NU Clinical and Translational Sciences Institute',
                        'Office of Finance and Administration',
                       'Office for Research'

                      ]  # Replace with the names of departments to drop

# Step 7: Filter out entries from the specified departments
lcme_df_3 = lcme_df_2[~lcme_df_2['Department'].isin(departments_to_drop)]

## Print unique department names after replacement
print("Unique department names after replacement:", lcme_df_3['Department'].unique())

duplicate_count = lcme_df_3.duplicated(subset=['Department', 'Publication ID']).sum()
print(f"Number of duplicate entries in lcme_df_3: {duplicate_count}")


lcme_df_3.head()
# Out:
# Unique department names after replacement: ['Preventive Medicine' 'Medicine' 'Obstetrics and Gynecology'
#  'Dermatology' 'Ophthalmology' 'Urology' 'Medical Social Sciences'
#  'Emergency Medicine' 'Pediatrics' 'Psychiatry and Behavioral Sciences'
#  'Surgery' 'Neurological Surgery'
#  'Physical Therapy and Human Movement Sciences' 'Neurology'
#  'Orthopaedic Surgery' 'Physical Medicine and Rehabilitation' 'Radiology'
#  'Pathology' 'Otolaryngology' 'Anesthesiology' 'Microbiology-Immunology'
#  'Medical Education' 'Radiation Oncology' 'Pharmacology'
#  'Biochemistry and Molecular Genetics' 'Cell & Developmental Biology'
#  'Molecular Biosciences' 'Family and Community Medicine']
# Number of duplicate entries in lcme_df_3: 3060
#    Group ID  User ID             Name                     Position  \
# 0        15    11346    Leah Neubauer          Associate Professor
# 1        15     3773    Joshua Hauser                    Professor
# 2        15     2617  William Grobman            Adjunct Professor
# 3        15    13109     Emily Miller  Adjunct Associate Professor
# 4        15    10459         Lynn Yee          Associate Professor
#
#                   Department                       School  Employee ID  \
# 0        Preventive Medicine  Feinberg School of Medicine      2334590
# 1                   Medicine  Feinberg School of Medicine      1049388
# 2  Obstetrics and Gynecology  Feinberg School of Medicine      1027416
# 3  Obstetrics and Gynecology  Feinberg School of Medicine      2698434
# 4  Obstetrics and Gynecology  Feinberg School of Medicine      2001454
#
#     Net ID  Is Current Staff  Is Academic  ...              Scopus  \
# 0  lcn8717                 1            1  ...  2-s2.0-85184902556
# 1   jmh734                 1            1  ...  2-s2.0-85074861554
# 2   wag063                 1            1  ...  2-s2.0-85125994522
# 3   emi373                 1            1  ...  2-s2.0-85125994522
# 4   lmy505                 1            1  ...  2-s2.0-85125621164
#
#         Web of Science                       Crossref      PubMed  \
# 0                  NaN               10.1002/ev.20577         NaN
# 1                  NaN  10.1136/bmjspcare-2019-001928  31685523.0
# 2  WOS:001188015800009            10.1055/a-1745-0091  35045575.0
# 3  WOS:001188015800009            10.1055/a-1745-0091  35045575.0
# 4  WOS:000758393600002         10.1055/s-0042-1743184  35189652.0
#
#   Europe PubMed Central Max PR Pub ID Max PR NIHMS Max PR PMCID Max PR PMID  \
# 0                   NaN       1137050          NaN          NaN         NaN
# 1          MED:31685523       3261956          NaN          NaN         NaN
# 2          MED:35045575       3281092          NaN          NaN         NaN
# 3          MED:35045575       3281092          NaN          NaN         NaN
# 4          MED:35189652       3281107          NaN          NaN         NaN
#
#      Max PR PubMed
# 0              NaN
# 1  pubmed:31685523
# 2  pubmed:35045575
# 3  pubmed:35045575
# 4  pubmed:35189652
#
# [5 rows x 36 columns]

# %%
# Step 8: Remove duplicate publications for each department
# Assuming the unique identifier column is named 'unique_id'
lcme_df_4 = lcme_df_3[['Publication ID', 'title', 'Department', 'Type']].drop_duplicates()

print(f"Shape of lcme_df_3: {lcme_df_3.shape}")
print(f"Shape of lcme_df_4: {lcme_df_4.shape}")

# # Show the first few rows of lcme_df_3 and lcme_df_4 for comparison
# print("Sample data from lcme_df_3:")
# print(lcme_df_3[['Department', 'Publication ID']].head(10))

# print("\nSample data from lcme_df_4:")
# print(lcme_df_4[['Department', 'Publication ID']].head(10))

print("Unique publication IDs in lcme_df_4:", lcme_df_4['Publication ID'].nunique())
print("Unique departments in lcme_df_4:", lcme_df_4['Department'].nunique())


lcme_df_4.head(20)
# Out:
# Shape of lcme_df_3: (11493, 36)
# Shape of lcme_df_4: (8433, 4)
# Unique publication IDs in lcme_df_4: 7240
# Unique departments in lcme_df_4: 28
#     Publication ID                                              title  \
# 0          1137050                                     Editors’ notes
# 1          3261956  Adult palliative care in the USA: information-...
# 2          3281092  The Diagnostic Utility of Growth Ultrasound fo...
# 4          3281107  Perinatal Outcomes of Twin Gestations with and...
# 5          3294670  Complementary and Alternative Therapies for Ps...
# 6          3405416  Adaptive spectroscopic visible-light optical c...
# 7          3429077  Characteristics Associated with Trial of Labor...
# 8          3431897  Characteristics of men who use direct-to-consu...
# 11         3434899  Fatigue in newly diagnosed acute myeloid leuka...
# 13         3466591  Rapid Emergency Department Physical Space Modi...
# 20         3471102  Urine Quantification Following Furosemide for ...
# 22         3472061  Serum Cotinine and Adverse Cardiovascular Outc...
# 23         3474552  Trends in heroin use and injection drug use am...
# 24         3476463  The Association Between Immediate Postpartum D...
# 25         3476463  The Association Between Immediate Postpartum D...
# 26         3476474  Oral Glucose Tolerance Test in Pregnancy and S...
# 27         3479525  Peak insulin drip rate associated with decreas...
# 28         3479525  Peak insulin drip rate associated with decreas...
# 33         3479811  Fetal Tachycardia in the Setting of Maternal I...
# 34         3483757  The Association of Twin Chorionicity with Mate...
#
#                             Department             Type
# 0                  Preventive Medicine  Journal article
# 1                             Medicine  Journal article
# 2            Obstetrics and Gynecology       Conference
# 4            Obstetrics and Gynecology       Conference
# 5                          Dermatology  Journal article
# 6                        Ophthalmology       Conference
# 7            Obstetrics and Gynecology       Conference
# 8                              Urology       Conference
# 11             Medical Social Sciences  Journal article
# 13                  Emergency Medicine  Journal article
# 20                          Pediatrics  Journal article
# 22           Obstetrics and Gynecology  Journal article
# 23             Medical Social Sciences  Journal article
# 24  Psychiatry and Behavioral Sciences  Journal article
# 25           Obstetrics and Gynecology  Journal article
# 26           Obstetrics and Gynecology  Journal article
# 27                            Medicine       Conference
# 28                             Surgery       Conference
# 33           Obstetrics and Gynecology  Journal article
# 34           Obstetrics and Gynecology  Journal article

# %%
# Step 7: Count unique document types by department
# Create a pivot table to count the unique document types
lcme_df_5 = lcme_df_4.pivot_table(index='Department', 
                                               columns='Type', 
                                               values='Publication ID', 
                                               aggfunc='nunique', 
                                               fill_value=0)


print(f"Original unique publication count: {original_count}")
print(f"New unique publication count after removing duplicates: {new_count}")

# Display the result
lcme_df_5.head(20)
# Out:
# Original unique publication count: 11493
# New unique publication count after removing duplicates: 8433
# Type                                 Book  Chapter  Conference  \
# Department
# Anesthesiology                          0        1           1
# Biochemistry and Molecular Genetics     0        1           3
# Cell & Developmental Biology            0        2           7
# Dermatology                             0        1           2
# Emergency Medicine                      0        1           1
# Family and Community Medicine           0        0           0
# Medical Education                       2        3           3
# Medical Social Sciences                 0        2          10
# Medicine                                0        7          78
# Microbiology-Immunology                 0        0           4
# Molecular Biosciences                   0        0           0
# Neurological Surgery                    0        0          21
# Neurology                               1        1          10
# Obstetrics and Gynecology               0        2          17
# Ophthalmology                           0       12           3
# Orthopaedic Surgery                     0       19           0
# Otolaryngology                          1        9           0
# Pathology                               0        2           5
# Pediatrics                              2       16          16
# Pharmacology                            0        1           0
#
# Type                                 Internet publication  Journal article  \
# Department
# Anesthesiology                                          1              104
# Biochemistry and Molecular Genetics                     0               78
# Cell & Developmental Biology                            0               79
# Dermatology                                             0              259
# Emergency Medicine                                      0               69
# Family and Community Medicine                           0               11
# Medical Education                                       0              125
# Medical Social Sciences                                 1              533
# Medicine                                                1             1643
# Microbiology-Immunology                                 0               64
# Molecular Biosciences                                   0                3
# Neurological Surgery                                    0              264
# Neurology                                               0              390
# Obstetrics and Gynecology                               0              323
# Ophthalmology                                           0              113
# Orthopaedic Surgery                                     0              107
# Otolaryngology                                          0               76
# Pathology                                               0              258
# Pediatrics                                              0             1005
# Pharmacology                                            0               85
#
# Type                                 Other  Poster  Preprint  Report
# Department
# Anesthesiology                           0       0         0       0
# Biochemistry and Molecular Genetics      0       0         1       0
# Cell & Developmental Biology             0       0         2       0
# Dermatology                              0       0         0       0
# Emergency Medicine                       0       0         0       0
# Family and Community Medicine            0       0         0       0
# Medical Education                        0       0         1       0
# Medical Social Sciences                  0       0         4       0
# Medicine                                 3       0         7       0
# Microbiology-Immunology                  0       0         2       0
# Molecular Biosciences                    0       0         0       0
# Neurological Surgery                     0       0         2       0
# Neurology                                0       0         3       0
# Obstetrics and Gynecology                0       0         0       0
# Ophthalmology                            0       0         0       0
# Orthopaedic Surgery                      0       0         0       0
# Otolaryngology                           0       0         0       0
# Pathology                                0       0         2       0
# Pediatrics                               1       1         0       0
# Pharmacology                             0       0         0       0

# %%
# Step 9: Make any final edits

# Drop the 'Book' and 'Chapter' columns
lcme_df_6 = lcme_df_5.drop(columns=['Conference', 'Internet publication', 'Other', 'Poster', 'Preprint', 'Report'])


## Create a new column for merged counts
lcme_df_6['Published Books/Book Chapters'] = lcme_df_6['Book'] + lcme_df_6['Chapter']

# Drop the 'Book' and 'Chapter' columns
lcme_df_7 = lcme_df_6.drop(columns=['Book', 'Chapter'])

# Rename the "Journal Article" column
lcme_df_8 = lcme_df_7.rename(columns={'Journal article': 'Articles in Peer-reviewed Journals'}) 

lcme_df_8.head(20)
# Out:
# Type                                 Articles in Peer-reviewed Journals  \
# Department
# Anesthesiology                                                      104
# Biochemistry and Molecular Genetics                                  78
# Cell & Developmental Biology                                         79
# Dermatology                                                         259
# Emergency Medicine                                                   69
# Family and Community Medicine                                        11
# Medical Education                                                   125
# Medical Social Sciences                                             533
# Medicine                                                           1643
# Microbiology-Immunology                                              64
# Molecular Biosciences                                                 3
# Neurological Surgery                                                264
# Neurology                                                           390
# Obstetrics and Gynecology                                           323
# Ophthalmology                                                       113
# Orthopaedic Surgery                                                 107
# Otolaryngology                                                       76
# Pathology                                                           258
# Pediatrics                                                         1005
# Pharmacology                                                         85
#
# Type                                 Published Books/Book Chapters
# Department
# Anesthesiology                                                   1
# Biochemistry and Molecular Genetics                              1
# Cell & Developmental Biology                                     2
# Dermatology                                                      1
# Emergency Medicine                                               1
# Family and Community Medicine                                    0
# Medical Education                                                5
# Medical Social Sciences                                          2
# Medicine                                                         7
# Microbiology-Immunology                                          0
# Molecular Biosciences                                            0
# Neurological Surgery                                             0
# Neurology                                                        2
# Obstetrics and Gynecology                                        2
# Ophthalmology                                                   12
# Orthopaedic Surgery                                             19
# Otolaryngology                                                  10
# Pathology                                                        2
# Pediatrics                                                      18
# Pharmacology                                                     1

# %%
# Step 10: Export the pivot table to an Excel file

output_file_path = 'output/department_document_counts.xlsx'  # Define your output file name
lcme_df_8.to_excel(output_file_path, sheet_name='Counts')
